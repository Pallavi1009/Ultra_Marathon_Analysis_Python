# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# <ipython-input-3-573a4a22143a>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/drive/MyDrive/TWO_CENTURIES_OF_UM_RACES.csv')

# %%
df.head(5)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df=df[df['Athlete country']=='IND']
df
# Out:
#          Year of event     Event dates  \
# 5829              2018      18.03.2018
# 5843              2018      18.03.2018
# 10779             2018      17.03.2018
# 16245             2018      17.03.2018
# 18624             2018      17.03.2018
# ...                ...             ...
# 7110133           1987  16.-17.11.1987
# 7220116           1990  13.-19.10.1990
# 7449348           1995      29.04.1995
# 7449349           1995      29.04.1995
# 7449350           1995      29.04.1995
#
#                                             Event name Event distance/length  \
# 5829               TITI 50km Road Ultra Marathon (MAS)                  50km
# 5843               TITI 50km Road Ultra Marathon (MAS)                  50km
# 10779    EcoTrail de Paris - Ile de France 45 km (FRA)                  45km
# 16245                            Om Die Dam 50km (RSA)                  50km
# 18624                          Dalat Ultra Trail (VIE)                  70km
# ...                                                ...                   ...
# 7110133               Six-Days-Colac - 24h Split (AUS)                   24h
# 7220116             Six Day Track Race Gateshead (GBR)                    6d
# 7449348       IAAF World Race Walking Cup - 50km (CHN)                  50km
# 7449349       IAAF World Race Walking Cup - 50km (CHN)                  50km
# 7449350       IAAF World Race Walking Cup - 50km (CHN)                  50km
#
#          Event number of finishers Athlete performance  \
# 5829                           282           8:37:30 h
# 5843                           282           8:44:07 h
# 10779                         1393           6:09:40 h
# 16245                         2491           5:18:55 h
# 18624                          135           9:21:59 h
# ...                            ...                 ...
# 7110133                         16          133.200 km
# 7220116                         13          516.220 km
# 7449348                         85           5:04:33 h
# 7449349                         85           5:04:33 h
# 7449350                         85           5:21:17 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 5829                           NaN             IND                    NaN
# 5843                           NaN             IND                 1977.0
# 10779                  *Heidelberg             IND                 1990.0
# 16245    Brackenfell Athletics ...             IND                 1988.0
# 18624                          NaN             IND                 1986.0
# ...                            ...             ...                    ...
# 7110133                        NaN             IND                 1959.0
# 7220116                        NaN             IND                 1959.0
# 7449348                        NaN             IND                    NaN
# 7449349                        NaN             IND                    NaN
# 7449350                        NaN             IND                 1969.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 5829                 M                  NaN                 5.797        5197
# 5843                 M                  M40                 5.724        5211
# 10779                M                  M23                 7.304       10112
# 16245                M                  M23                 9.407       15497
# 18624                M                  M23                 7.474       17865
# ...                ...                  ...                   ...         ...
# 7110133              M                  M23                5550.0     1598983
# 7220116              M                  M23                3585.0     1598983
# 7449348              M                  NaN                9851.0     1640502
# 7449349              M                  NaN                9851.0     1640503
# 7449350              M                  M23                9338.0      257872
#
# [16677 rows x 13 columns]

# %%
len(df['Event distance/length'].unique())
# Out:
# 215

# %%
df['Event distance/length'].value_counts()
# Out:
# Event distance/length
# 50km      6008
# 12h       1757
# 100km      981
# 24h        911
# 60km       583
#           ...
# 28h          1
# 63.6km       1
# 46.7km       1
# 65.3km       1
# 71.5km       1
# Name: count, Length: 215, dtype: int64

# %%
#keep only the 50km,100km,12hours and 24 hours as they are the most frequent values
df=df[df['Event distance/length'].isin(['50km','100km','12h','24h'])]
df
# Out:
#          Year of event     Event dates  \
# 5829              2018      18.03.2018
# 5843              2018      18.03.2018
# 16245             2018      17.03.2018
# 23416             2018      10.03.2018
# 24745             2018      10.03.2018
# ...                ...             ...
# 6827568           1960      07.09.1960
# 7110133           1987  16.-17.11.1987
# 7449348           1995      29.04.1995
# 7449349           1995      29.04.1995
# 7449350           1995      29.04.1995
#
#                                        Event name Event distance/length  \
# 5829          TITI 50km Road Ultra Marathon (MAS)                  50km
# 5843          TITI 50km Road Ultra Marathon (MAS)                  50km
# 16245                       Om Die Dam 50km (RSA)                  50km
# 23416                         North C Trail (BEL)                  50km
# 24745           Crazy Desert Trail Race 50k (USA)                  50km
# ...                                           ...                   ...
# 6827568    Summer Olympic Games - 50km Walk (ITA)                  50km
# 7110133          Six-Days-Colac - 24h Split (AUS)                   24h
# 7449348  IAAF World Race Walking Cup - 50km (CHN)                  50km
# 7449349  IAAF World Race Walking Cup - 50km (CHN)                  50km
# 7449350  IAAF World Race Walking Cup - 50km (CHN)                  50km
#
#          Event number of finishers Athlete performance  \
# 5829                           282           8:37:30 h
# 5843                           282           8:44:07 h
# 16245                         2491           5:18:55 h
# 23416                          192           8:04:30 h
# 24745                           59           6:21:38 h
# ...                            ...                 ...
# 6827568                         28           4:47:29 h
# 7110133                         16          133.200 km
# 7449348                         85           5:04:33 h
# 7449349                         85           5:04:33 h
# 7449350                         85           5:21:17 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 5829                           NaN             IND                    NaN
# 5843                           NaN             IND                 1977.0
# 16245    Brackenfell Athletics ...             IND                 1988.0
# 23416                          NaN             IND                 1990.0
# 24745                  *Dallas, TX             IND                 1987.0
# ...                            ...             ...                    ...
# 6827568                        NaN             IND                 1936.0
# 7110133                        NaN             IND                 1959.0
# 7449348                        NaN             IND                    NaN
# 7449349                        NaN             IND                    NaN
# 7449350                        NaN             IND                 1969.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 5829                 M                  NaN                 5.797        5197
# 5843                 M                  M40                 5.724        5211
# 16245                M                  M23                 9.407       15497
# 23416                F                  W23                 6.192       22117
# 24745                M                  M23                 7.861       23372
# ...                ...                  ...                   ...         ...
# 6827568              M                  M23               10435.0     1522048
# 7110133              M                  M23                5550.0     1598983
# 7449348              M                  NaN                9851.0     1640502
# 7449349              M                  NaN                9851.0     1640503
# 7449350              M                  M23                9338.0      257872
#
# [9657 rows x 13 columns]

# %%
df['Athlete club'].value_counts()
# Out:
# Athlete club
# *Bangalore               285
# *Mumbai                  228
# *Chennai                 104
# *Pune                     74
# *Bengaluru                44
#                         ...
# *Atlanta, GA               1
# *Ajax                      1
# *Bengalore                 1
# Brackenfell Athletics      1
# *Nairobi                   1
# Name: count, Length: 332, dtype: int64

# %%
#check for null values
df['Athlete club'].isnull().sum()
# Out:
# 8126

# %%
df['Event name'].value_counts()
# Out:
# Event name
# The Malnad Ultra 50K (IND)               666
# Bangalore 50 km Ultra Marathon (IND)     661
# Tata Ultra Marathon (IND)                486
# Bengaluru 12 Hour Stadium Run (IND)      425
# Mumbai 12 Hour Stadium Run (IND)         320
#                                         ...
# Runners Wild Bario (MAS)                   1
# 3 Days at the Fair 12 Hour Race (USA)      1
# London 2 Brighton Challenge (GBR)          1
# MSIG Lantau 50 (HKG)                       1
# Hashawha Hills 50 km Trail Run (USA)       1
# Name: count, Length: 538, dtype: int64

# %%
df.isnull().sum()
# Out:
# Year of event                   0
# Event dates                     0
# Event name                      0
# Event distance/length           0
# Event number of finishers       0
# Athlete performance             0
# Athlete club                 8126
# Athlete country                 0
# Athlete year of birth        3300
# Athlete gender                  0
# Athlete age category         3300
# Athlete average speed           0
# Athlete ID                      0
# dtype: int64

# %%
#Drop na values
df=df.dropna(subset=['Athlete year of birth'])
df
# Out:
#          Year of event     Event dates  \
# 5843              2018      18.03.2018
# 16245             2018      17.03.2018
# 23416             2018      10.03.2018
# 24745             2018      10.03.2018
# 25299             2018      10.03.2018
# ...                ...             ...
# 6821569           2015      10.10.2015
# 6827561           1960      07.09.1960
# 6827568           1960      07.09.1960
# 7110133           1987  16.-17.11.1987
# 7449350           1995      29.04.1995
#
#                                        Event name Event distance/length  \
# 5843          TITI 50km Road Ultra Marathon (MAS)                  50km
# 16245                       Om Die Dam 50km (RSA)                  50km
# 23416                         North C Trail (BEL)                  50km
# 24745           Crazy Desert Trail Race 50k (USA)                  50km
# 25299                   Dirty Duo Trail Run (CAN)                  50km
# ...                                           ...                   ...
# 6821569           Annapurna 50k Ultra Trail (NEP)                  50km
# 6827561    Summer Olympic Games - 50km Walk (ITA)                  50km
# 6827568    Summer Olympic Games - 50km Walk (ITA)                  50km
# 7110133          Six-Days-Colac - 24h Split (AUS)                   24h
# 7449350  IAAF World Race Walking Cup - 50km (CHN)                  50km
#
#          Event number of finishers Athlete performance  \
# 5843                           282           8:44:07 h
# 16245                         2491           5:18:55 h
# 23416                          192           8:04:30 h
# 24745                           59           6:21:38 h
# 25299                           34           4:58:08 h
# ...                            ...                 ...
# 6821569                         36          14:04:20 h
# 6827561                         28           4:37:45 h
# 6827568                         28           4:47:29 h
# 7110133                         16          133.200 km
# 7449350                         85           5:21:17 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 5843                           NaN             IND                 1977.0
# 16245    Brackenfell Athletics ...             IND                 1988.0
# 23416                          NaN             IND                 1990.0
# 24745                  *Dallas, TX             IND                 1987.0
# 25299                          NaN             IND                 1980.0
# ...                            ...             ...                    ...
# 6821569                        NaN             IND                 1976.0
# 6827561                        NaN             IND                 1928.0
# 6827568                        NaN             IND                 1936.0
# 7110133                        NaN             IND                 1959.0
# 7449350                        NaN             IND                 1969.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 5843                 M                  M40                 5.724        5211
# 16245                M                  M23                 9.407       15497
# 23416                F                  W23                 6.192       22117
# 24745                M                  M23                 7.861       23372
# 25299                M                  M35                10.063       23912
# ...                ...                  ...                   ...         ...
# 6821569              M                  M35                 3.553      444467
# 6827561              M                  M23               10801.0     1522043
# 6827568              M                  M23               10435.0     1522048
# 7110133              M                  M23                5550.0     1598983
# 7449350              M                  M23                9338.0      257872
#
# [6357 rows x 13 columns]

# %%
#lets get out athlete's age
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df['Athlete year of birth'].value_counts()
# Out:
# Athlete year of birth
# 1980.0    331
# 1987.0    285
# 1982.0    277
# 1979.0    274
# 1978.0    271
#          ...
# 1933.0      1
# 2010.0      1
# 2003.0      1
# 1928.0      1
# 1936.0      1
# Name: count, Length: 61, dtype: int64

# %%
df['Athlete year of birth']=df['Athlete year of birth'].astype('int64')
df
# Out:
#          Year of event     Event dates  \
# 5843              2018      18.03.2018
# 16245             2018      17.03.2018
# 23416             2018      10.03.2018
# 24745             2018      10.03.2018
# 25299             2018      10.03.2018
# ...                ...             ...
# 6821569           2015      10.10.2015
# 6827561           1960      07.09.1960
# 6827568           1960      07.09.1960
# 7110133           1987  16.-17.11.1987
# 7449350           1995      29.04.1995
#
#                                        Event name Event distance/length  \
# 5843          TITI 50km Road Ultra Marathon (MAS)                  50km
# 16245                       Om Die Dam 50km (RSA)                  50km
# 23416                         North C Trail (BEL)                  50km
# 24745           Crazy Desert Trail Race 50k (USA)                  50km
# 25299                   Dirty Duo Trail Run (CAN)                  50km
# ...                                           ...                   ...
# 6821569           Annapurna 50k Ultra Trail (NEP)                  50km
# 6827561    Summer Olympic Games - 50km Walk (ITA)                  50km
# 6827568    Summer Olympic Games - 50km Walk (ITA)                  50km
# 7110133          Six-Days-Colac - 24h Split (AUS)                   24h
# 7449350  IAAF World Race Walking Cup - 50km (CHN)                  50km
#
#          Event number of finishers Athlete performance  \
# 5843                           282           8:44:07 h
# 16245                         2491           5:18:55 h
# 23416                          192           8:04:30 h
# 24745                           59           6:21:38 h
# 25299                           34           4:58:08 h
# ...                            ...                 ...
# 6821569                         36          14:04:20 h
# 6827561                         28           4:37:45 h
# 6827568                         28           4:47:29 h
# 7110133                         16          133.200 km
# 7449350                         85           5:21:17 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 5843                           NaN             IND                   1977
# 16245    Brackenfell Athletics ...             IND                   1988
# 23416                          NaN             IND                   1990
# 24745                  *Dallas, TX             IND                   1987
# 25299                          NaN             IND                   1980
# ...                            ...             ...                    ...
# 6821569                        NaN             IND                   1976
# 6827561                        NaN             IND                   1928
# 6827568                        NaN             IND                   1936
# 7110133                        NaN             IND                   1959
# 7449350                        NaN             IND                   1969
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 5843                 M                  M40                 5.724        5211
# 16245                M                  M23                 9.407       15497
# 23416                F                  W23                 6.192       22117
# 24745                M                  M23                 7.861       23372
# 25299                M                  M35                10.063       23912
# ...                ...                  ...                   ...         ...
# 6821569              M                  M35                 3.553      444467
# 6827561              M                  M23               10801.0     1522043
# 6827568              M                  M23               10435.0     1522048
# 7110133              M                  M23                5550.0     1598983
# 7449350              M                  M23                9338.0      257872
#
# [6357 rows x 13 columns]

# %%
#Athlete Age
df['Athlete_Age']=df['Year of event']-df['Athlete year of birth']
df
# Out:
#          Year of event     Event dates  \
# 5843              2018      18.03.2018
# 16245             2018      17.03.2018
# 23416             2018      10.03.2018
# 24745             2018      10.03.2018
# 25299             2018      10.03.2018
# ...                ...             ...
# 6821569           2015      10.10.2015
# 6827561           1960      07.09.1960
# 6827568           1960      07.09.1960
# 7110133           1987  16.-17.11.1987
# 7449350           1995      29.04.1995
#
#                                        Event name Event distance/length  \
# 5843          TITI 50km Road Ultra Marathon (MAS)                  50km
# 16245                       Om Die Dam 50km (RSA)                  50km
# 23416                         North C Trail (BEL)                  50km
# 24745           Crazy Desert Trail Race 50k (USA)                  50km
# 25299                   Dirty Duo Trail Run (CAN)                  50km
# ...                                           ...                   ...
# 6821569           Annapurna 50k Ultra Trail (NEP)                  50km
# 6827561    Summer Olympic Games - 50km Walk (ITA)                  50km
# 6827568    Summer Olympic Games - 50km Walk (ITA)                  50km
# 7110133          Six-Days-Colac - 24h Split (AUS)                   24h
# 7449350  IAAF World Race Walking Cup - 50km (CHN)                  50km
#
#          Event number of finishers Athlete performance  \
# 5843                           282           8:44:07 h
# 16245                         2491           5:18:55 h
# 23416                          192           8:04:30 h
# 24745                           59           6:21:38 h
# 25299                           34           4:58:08 h
# ...                            ...                 ...
# 6821569                         36          14:04:20 h
# 6827561                         28           4:37:45 h
# 6827568                         28           4:47:29 h
# 7110133                         16          133.200 km
# 7449350                         85           5:21:17 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 5843                           NaN             IND                   1977
# 16245    Brackenfell Athletics ...             IND                   1988
# 23416                          NaN             IND                   1990
# 24745                  *Dallas, TX             IND                   1987
# 25299                          NaN             IND                   1980
# ...                            ...             ...                    ...
# 6821569                        NaN             IND                   1976
# 6827561                        NaN             IND                   1928
# 6827568                        NaN             IND                   1936
# 7110133                        NaN             IND                   1959
# 7449350                        NaN             IND                   1969
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 5843                 M                  M40                 5.724        5211
# 16245                M                  M23                 9.407       15497
# 23416                F                  W23                 6.192       22117
# 24745                M                  M23                 7.861       23372
# 25299                M                  M35                10.063       23912
# ...                ...                  ...                   ...         ...
# 6821569              M                  M35                 3.553      444467
# 6827561              M                  M23               10801.0     1522043
# 6827568              M                  M23               10435.0     1522048
# 7110133              M                  M23                5550.0     1598983
# 7449350              M                  M23                9338.0      257872
#
#          Athlete_Age
# 5843              41
# 16245             30
# 23416             28
# 24745             31
# 25299             38
# ...              ...
# 6821569           39
# 6827561           32
# 6827568           24
# 7110133           28
# 7449350           26
#
# [6357 rows x 14 columns]

# %%
# removed the 'h' from the Athlete performance
df['Athlete performance']=df['Athlete performance'].str.split(' ').str.get(0)
df
# Out:
#          Year of event     Event dates  \
# 5843              2018      18.03.2018
# 16245             2018      17.03.2018
# 23416             2018      10.03.2018
# 24745             2018      10.03.2018
# 25299             2018      10.03.2018
# ...                ...             ...
# 6821569           2015      10.10.2015
# 6827561           1960      07.09.1960
# 6827568           1960      07.09.1960
# 7110133           1987  16.-17.11.1987
# 7449350           1995      29.04.1995
#
#                                        Event name Event distance/length  \
# 5843          TITI 50km Road Ultra Marathon (MAS)                  50km
# 16245                       Om Die Dam 50km (RSA)                  50km
# 23416                         North C Trail (BEL)                  50km
# 24745           Crazy Desert Trail Race 50k (USA)                  50km
# 25299                   Dirty Duo Trail Run (CAN)                  50km
# ...                                           ...                   ...
# 6821569           Annapurna 50k Ultra Trail (NEP)                  50km
# 6827561    Summer Olympic Games - 50km Walk (ITA)                  50km
# 6827568    Summer Olympic Games - 50km Walk (ITA)                  50km
# 7110133          Six-Days-Colac - 24h Split (AUS)                   24h
# 7449350  IAAF World Race Walking Cup - 50km (CHN)                  50km
#
#          Event number of finishers Athlete performance  \
# 5843                           282             8:44:07
# 16245                         2491             5:18:55
# 23416                          192             8:04:30
# 24745                           59             6:21:38
# 25299                           34             4:58:08
# ...                            ...                 ...
# 6821569                         36            14:04:20
# 6827561                         28             4:37:45
# 6827568                         28             4:47:29
# 7110133                         16             133.200
# 7449350                         85             5:21:17
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 5843                           NaN             IND                   1977
# 16245    Brackenfell Athletics ...             IND                   1988
# 23416                          NaN             IND                   1990
# 24745                  *Dallas, TX             IND                   1987
# 25299                          NaN             IND                   1980
# ...                            ...             ...                    ...
# 6821569                        NaN             IND                   1976
# 6827561                        NaN             IND                   1928
# 6827568                        NaN             IND                   1936
# 7110133                        NaN             IND                   1959
# 7449350                        NaN             IND                   1969
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 5843                 M                  M40                 5.724        5211
# 16245                M                  M23                 9.407       15497
# 23416                F                  W23                 6.192       22117
# 24745                M                  M23                 7.861       23372
# 25299                M                  M35                10.063       23912
# ...                ...                  ...                   ...         ...
# 6821569              M                  M35                 3.553      444467
# 6827561              M                  M23               10801.0     1522043
# 6827568              M                  M23               10435.0     1522048
# 7110133              M                  M23                5550.0     1598983
# 7449350              M                  M23                9338.0      257872
#
#          Athlete_Age
# 5843              41
# 16245             30
# 23416             28
# 24745             31
# 25299             38
# ...              ...
# 6821569           39
# 6827561           32
# 6827568           24
# 7110133           28
# 7449350           26
#
# [6357 rows x 14 columns]

# %%
df=df.drop_duplicates()

# %%
df=df.reset_index()

# %%
df['Athlete average speed']=df['Athlete average speed'].astype('float64')

# %%
df = df[df['Athlete average speed'] < 20]
df
# Out:
#         index  Year of event     Event dates  \
# 0        5843           2018      18.03.2018
# 1       16245           2018      17.03.2018
# 2       23416           2018      10.03.2018
# 3       24745           2018      10.03.2018
# 4       25299           2018      10.03.2018
# ...       ...            ...             ...
# 6348  6776097           2015  07.-08.11.2015
# 6349  6783641           2015      31.10.2015
# 6350  6819032           2015      10.10.2015
# 6351  6821563           2015      10.10.2015
# 6352  6821569           2015      10.10.2015
#
#                                        Event name Event distance/length  \
# 0             TITI 50km Road Ultra Marathon (MAS)                  50km
# 1                           Om Die Dam 50km (RSA)                  50km
# 2                             North C Trail (BEL)                  50km
# 3               Crazy Desert Trail Race 50k (USA)                  50km
# 4                       Dirty Duo Trail Run (CAN)                  50km
# ...                                           ...                   ...
# 6348       Bangalore 24 hour Ultra Marathon (IND)                   24h
# 6349  Bedok Reservoir 12 hour Ultramarathon (SGP)                   12h
# 6350            The North Face 50 Singapore (SGP)                  50km
# 6351              Annapurna 50k Ultra Trail (NEP)                  50km
# 6352              Annapurna 50k Ultra Trail (NEP)                  50km
#
#       Event number of finishers Athlete performance  \
# 0                           282             8:44:07
# 1                          2491             5:18:55
# 2                           192             8:04:30
# 3                            59             6:21:38
# 4                            34             4:58:08
# ...                         ...                 ...
# 6348                         25             102.000
# 6349                        148              51.600
# 6350                        269             3:58:20
# 6351                         36            12:40:30
# 6352                         36            14:04:20
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 0                           NaN             IND                   1977
# 1     Brackenfell Athletics ...             IND                   1988
# 2                           NaN             IND                   1990
# 3                   *Dallas, TX             IND                   1987
# 4                           NaN             IND                   1980
# ...                         ...             ...                    ...
# 6348                        NaN             IND                   1980
# 6349                        NaN             IND                   1978
# 6350                        NaN             IND                   1980
# 6351                        NaN             IND                   1976
# 6352                        NaN             IND                   1976
#
#      Athlete gender Athlete age category  Athlete average speed  Athlete ID  \
# 0                 M                  M40                  5.724        5211
# 1                 M                  M23                  9.407       15497
# 2                 F                  W23                  6.192       22117
# 3                 M                  M23                  7.861       23372
# 4                 M                  M35                 10.063       23912
# ...             ...                  ...                    ...         ...
# 6348              F                  W35                  4.250       68462
# 6349              M                  M35                  4.300       25241
# 6350              M                  M35                 12.587       23912
# 6351              M                  M35                  3.945      396014
# 6352              M                  M35                  3.553      444467
#
#       Athlete_Age
# 0              41
# 1              30
# 2              28
# 3              31
# 4              38
# ...           ...
# 6348           35
# 6349           37
# 6350           35
# 6351           39
# 6352           39
#
# [6353 rows x 15 columns]

# %%
df=df.drop(['Athlete club','Athlete year of birth'],axis=1)

# %%
#final data
df
# Out:
#         index  Year of event     Event dates  \
# 0        5843           2018      18.03.2018
# 1       16245           2018      17.03.2018
# 2       23416           2018      10.03.2018
# 3       24745           2018      10.03.2018
# 4       25299           2018      10.03.2018
# ...       ...            ...             ...
# 6348  6776097           2015  07.-08.11.2015
# 6349  6783641           2015      31.10.2015
# 6350  6819032           2015      10.10.2015
# 6351  6821563           2015      10.10.2015
# 6352  6821569           2015      10.10.2015
#
#                                        Event name Event distance/length  \
# 0             TITI 50km Road Ultra Marathon (MAS)                  50km
# 1                           Om Die Dam 50km (RSA)                  50km
# 2                             North C Trail (BEL)                  50km
# 3               Crazy Desert Trail Race 50k (USA)                  50km
# 4                       Dirty Duo Trail Run (CAN)                  50km
# ...                                           ...                   ...
# 6348       Bangalore 24 hour Ultra Marathon (IND)                   24h
# 6349  Bedok Reservoir 12 hour Ultramarathon (SGP)                   12h
# 6350            The North Face 50 Singapore (SGP)                  50km
# 6351              Annapurna 50k Ultra Trail (NEP)                  50km
# 6352              Annapurna 50k Ultra Trail (NEP)                  50km
#
#       Event number of finishers Athlete performance Athlete country  \
# 0                           282             8:44:07             IND
# 1                          2491             5:18:55             IND
# 2                           192             8:04:30             IND
# 3                            59             6:21:38             IND
# 4                            34             4:58:08             IND
# ...                         ...                 ...             ...
# 6348                         25             102.000             IND
# 6349                        148              51.600             IND
# 6350                        269             3:58:20             IND
# 6351                         36            12:40:30             IND
# 6352                         36            14:04:20             IND
#
#      Athlete gender Athlete age category  Athlete average speed  Athlete ID  \
# 0                 M                  M40                  5.724        5211
# 1                 M                  M23                  9.407       15497
# 2                 F                  W23                  6.192       22117
# 3                 M                  M23                  7.861       23372
# 4                 M                  M35                 10.063       23912
# ...             ...                  ...                    ...         ...
# 6348              F                  W35                  4.250       68462
# 6349              M                  M35                  4.300       25241
# 6350              M                  M35                 12.587       23912
# 6351              M                  M35                  3.945      396014
# 6352              M                  M35                  3.553      444467
#
#       Athlete_Age
# 0              41
# 1              30
# 2              28
# 3              31
# 4              38
# ...           ...
# 6348           35
# 6349           37
# 6350           35
# 6351           39
# 6352           39
#
# [6353 rows x 13 columns]

# %% [markdown]
# ***Data Visualization***

# %%
# number of Athlete participated in each event
df['Event name'].value_counts().head().plot(kind='bar',title='No. of Athlete',xlabel='Event Name',ylabel='NO. of Athlete ',
                                           figsize=(10,6),color='pink')
# Out:
# <Axes: title={'center': 'No. of Athlete'}, xlabel='Event Name', ylabel='NO. of Athlete '>

# %%
#Athelete participated by gender in each Event distance/length.
sns.displot(data=df,kind='hist',x='Event distance/length',hue='Athlete gender')
plt.title('The Number of Race in 50 km,100 km,24h and 12h category By gender')
# Out:
# Text(0.5, 1.0, 'The Number of Race in 50 km,100 km,24h and 12h category By gender')

# %%
sns.displot(data=df,x='Athlete_Age',kind='hist',color='yellow',kde='True')
plt.title("Distributions of Athlete age")
# Out:
# Text(0.5, 1.0, 'Distributions of Athlete age')

# %%
sns.displot(data=df,x='Athlete average speed',color='red',kde=True)
plt.title("Distributions of Athlete average speed")
# Out:
# Text(0.5, 1.0, 'Distributions of Athlete average speed')

# %%
age_vs_speed=df.groupby(['Athlete age category'])['Athlete average speed'].agg(['mean','count']).sort_values(by='mean',ascending=False).query('count>20')
age_vs_speed
# Out:
#                           mean  count
# Athlete age category
# MU23                  7.627282    216
# M23                   7.262704   1974
# W50                   7.231467     30
# M35                   7.078349   1156
# W45                   6.946688     80
# M40                   6.939171    983
# M45                   6.863269    692
# W35                   6.821216    185
# W23                   6.705857    244
# M55                   6.692986    142
# M60                   6.681435     46
# W40                   6.653614    176
# M50                   6.638896    355

# %%
plt.figure(figsize=(10, 6))
plt.plot(age_vs_speed.index, age_vs_speed['mean'], marker='o', color='g', linestyle='-')
plt.xlabel('Age group')
plt.ylabel('Average Speed')
plt.title('Average speed vs Age')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
distance_gender=df.groupby(['Event distance/length','Athlete gender'])['Athlete average speed'].agg(['mean','count']).sort_values(by='mean',ascending=False)
data=distance_gender.reset_index()
data
# Out:
#   Event distance/length Athlete gender      mean  count
# 0                  50km              M  7.520869   3412
# 1                  50km              F  7.124495    392
# 2                 100km              F  6.944259     85
# 3                   12h              M  6.796552    899
# 4                   12h              F  6.574096    146
# 5                 100km              M  6.565604    719
# 6                   24h              F  5.798016    122
# 7                   24h              M  5.633988    578

# %% [markdown]
# **Athlete average speed by Event Distance and Gender**

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Event distance/length', y='mean', hue='Athlete gender', data=data)
plt.xlabel('Event distance/length')
plt.ylabel('Athlete average speed')
plt.title('Athlete average speed by Event Distance and Gender')
plt.legend(title='Athlete Gender')
plt.show()

# %%
distance = df.groupby(['Event distance/length','Athlete gender']).agg({'Athlete gender': 'count', 'Athlete average speed': ['mean', 'count']})
distance
# Out:
#                                      Athlete gender Athlete average speed  \
#                                               count                  mean
# Event distance/length Athlete gender
# 100km                 F                          85              6.944259
#                       M                         719              6.565604
# 12h                   F                         146              6.574096
#                       M                         899              6.796552
# 24h                   F                         122              5.798016
#                       M                         578              5.633988
# 50km                  F                         392              7.124495
#                       M                        3412              7.520869
#
#
#                                      count
# Event distance/length Athlete gender
# 100km                 F                 85
#                       M                719
# 12h                   F                146
#                       M                899
# 24h                   F                122
#                       M                578
# 50km                  F                392
#                       M               3412

# %% [markdown]
# **the relationship between the length of the race and athlethe average speed**

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data =df, x = 'Event distance/length', y='Athlete average speed', hue = 'Athlete gender', split = True, inner='quartz')
plt.tight_layout()

# %%
df2 = df[(df['Event distance/length'] == '50km') | (df['Event distance/length'] == '100km')]

# %%
df2
# Out:
#         index  Year of event Event dates  \
# 0        5843           2018  18.03.2018
# 1       16245           2018  17.03.2018
# 2       23416           2018  10.03.2018
# 3       24745           2018  10.03.2018
# 4       25299           2018  10.03.2018
# ...       ...            ...         ...
# 6335  6776065           2015  07.11.2015
# 6336  6776072           2015  07.11.2015
# 6350  6819032           2015  10.10.2015
# 6351  6821563           2015  10.10.2015
# 6352  6821569           2015  10.10.2015
#
#                                 Event name Event distance/length  \
# 0      TITI 50km Road Ultra Marathon (MAS)                  50km
# 1                    Om Die Dam 50km (RSA)                  50km
# 2                      North C Trail (BEL)                  50km
# 3        Crazy Desert Trail Race 50k (USA)                  50km
# 4                Dirty Duo Trail Run (CAN)                  50km
# ...                                    ...                   ...
# 6335  Bangalore 50 km Ultra Marathon (IND)                  50km
# 6336  Bangalore 50 km Ultra Marathon (IND)                  50km
# 6350     The North Face 50 Singapore (SGP)                  50km
# 6351       Annapurna 50k Ultra Trail (NEP)                  50km
# 6352       Annapurna 50k Ultra Trail (NEP)                  50km
#
#       Event number of finishers Athlete performance Athlete country  \
# 0                           282             8:44:07             IND
# 1                          2491             5:18:55             IND
# 2                           192             8:04:30             IND
# 3                            59             6:21:38             IND
# 4                            34             4:58:08             IND
# ...                         ...                 ...             ...
# 6335                         34             6:38:47             IND
# 6336                         34             9:35:25             IND
# 6350                        269             3:58:20             IND
# 6351                         36            12:40:30             IND
# 6352                         36            14:04:20             IND
#
#      Athlete gender Athlete age category  Athlete average speed  Athlete ID  \
# 0                 M                  M40                  5.724        5211
# 1                 M                  M23                  9.407       15497
# 2                 F                  W23                  6.192       22117
# 3                 M                  M23                  7.861       23372
# 4                 M                  M35                 10.063       23912
# ...             ...                  ...                    ...         ...
# 6335              M                  M50                  7.523      660700
# 6336              M                  M65                  5.214       68806
# 6350              M                  M35                 12.587       23912
# 6351              M                  M35                  3.945      396014
# 6352              M                  M35                  3.553      444467
#
#       Athlete_Age
# 0              41
# 1              30
# 2              28
# 3              31
# 4              38
# ...           ...
# 6335           50
# 6336           65
# 6350           35
# 6351           39
# 6352           39
#
# [4608 rows x 13 columns]

# %%
df2 = df[(df['Event distance/length'] == '50km') | (df['Event distance/length'] == '100km')]
sns.boxplot(y=df2['Athlete performance'].dt.hour,x=df2['Event distance/length'])
# Out:
# <Axes: xlabel='Event distance/length', ylabel='Athlete performance'>

# %%
df['Athlete_performance_in_hours']=df['Athlete performance'].dt.hour+(df['Athlete performance'].dt.minute/60)

# %%
events_by_hours=df.groupby('Event name')['Athlete_performance_in_hours'].agg(['mean','count','min','max']).query('count>20')
events_by_hours
# Out:
#                                                          mean  count  \
# Event name
# BNP Ultra (IND)                                      6.024272    103
# Bangalore 100 km Ultra Marathon (IND)               15.286458     80
# Bangalore 50 km Ultra Marathon (IND)                 6.420788    182
# Bengaluru 100 km Stadium Run (IND)                   9.472581     31
# Bhatti Lakes 100 km (IND)                           16.203846     39
# Bhatti Lakes 30 miles (IND)                          6.797989     58
# Chambal Challenge - Chambal Maharana 50 Km (IND)     5.904487     26
# Chennai Trail Marathon (IND)                         6.635069     48
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         6.398485     22
# Hennur Bamboo 100 Km Ultra (IND)                    18.674444     90
# Hennur Bamboo 50 Km Ultra (IND)                      7.594242    220
# Hyderabad Ultra Marathon (IND)                       6.070202     66
# Igatpuri Mountain Challenge (IND)                    6.704762     21
# Jarakabande Eco Ultra 100 Km (IND)                  18.355556     27
# Jarakabande Eco Ultra 50 Km (IND)                    8.152299     29
# Javadhu Hills Ultra 50 Km (IND)                      7.570833    104
# Lonavala Varsha Marathon (IND)                       6.272222     24
# Mahabaleshwar Endurathon (IND)                       7.068667     25
# Mahabaleshwar Endurathon 50 km (IND)                 9.883333     43
# Matheran Endurathon (IND)                            6.570940     78
# Matheran Endurathon - Summer Edition 50km (IND)      6.359524     28
# Mount Abu Int. Trail Marathon (IND)                  9.136574     36
# Mukteshwar Ultra Marathon (IND)                      6.852667     25
# Open National Race Walking Championship (IND)        4.526087     23
# Open National Race Walking Championship Kochi (...   4.338384     33
# Pagdandi Ultra Run (IND)                             6.611742     44
# Pune 100 km UltraMarathon (IND)                     15.018750     32
# Pune 50 km UltraMarathon (IND)                       5.940556     30
# Ruggedian Kolhapur Run (IND)                         5.803241     36
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     9.940240    111
# Shivalik Ultra Run 50 Km (IND)                       6.951307     51
# Tata Ultra Marathon (IND)                            6.080478    467
# The Border 100 - 100 Km Race (IND)                  14.980128     26
# The Great Mawla Ghaati Ultra 50km (IND)             10.074306     24
# The Malnad Ultra 50K (IND)                           8.107494    596
# The Run of Raramuri Tribe (TRORT) (IND)              6.671465     66
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           6.901923     26
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           7.144444     24
# Tuffman Stadium Run Chandigarh - 100km (IND)        11.155051     33
# Two Oceans Marathon - 50km Split (RSA)               5.753401     49
# Ultra Marathon Bengaluru (IND)                       5.993333    115
# Ultra Marathon Bengaluru December (IND)              6.350000     51
# Ultra Warrior Nainital (IND)                         8.367816     29
# Ultribe Paderu (IND)                                 9.388889     33
# Vagamon 50 Km Ultrail (IND)                          9.263946     49
# Yercaud Hills Ultra (IND)                            6.661364     22
#
#                                                           min        max
# Event name
# BNP Ultra (IND)                                      3.933333   8.066667
# Bangalore 100 km Ultra Marathon (IND)               10.100000  23.233333
# Bangalore 50 km Ultra Marathon (IND)                 3.933333   9.600000
# Bengaluru 100 km Stadium Run (IND)                   7.933333  13.350000
# Bhatti Lakes 100 km (IND)                           11.866667  17.933333
# Bhatti Lakes 30 miles (IND)                          4.950000   8.000000
# Chambal Challenge - Chambal Maharana 50 Km (IND)     4.000000   7.616667
# Chennai Trail Marathon (IND)                         4.750000   8.433333
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         4.083333   7.533333
# Hennur Bamboo 100 Km Ultra (IND)                    11.600000  23.916667
# Hennur Bamboo 50 Km Ultra (IND)                      4.233333  13.650000
# Hyderabad Ultra Marathon (IND)                       3.450000   9.183333
# Igatpuri Mountain Challenge (IND)                    5.266667   7.883333
# Jarakabande Eco Ultra 100 Km (IND)                  12.750000  22.566667
# Jarakabande Eco Ultra 50 Km (IND)                    4.966667  18.250000
# Javadhu Hills Ultra 50 Km (IND)                      4.683333  10.583333
# Lonavala Varsha Marathon (IND)                       4.200000   9.300000
# Mahabaleshwar Endurathon (IND)                       5.033333  10.416667
# Mahabaleshwar Endurathon 50 km (IND)                 6.200000  15.250000
# Matheran Endurathon (IND)                            4.266667   9.383333
# Matheran Endurathon - Summer Edition 50km (IND)      4.450000   7.933333
# Mount Abu Int. Trail Marathon (IND)                  4.900000  11.333333
# Mukteshwar Ultra Marathon (IND)                      4.850000   8.200000
# Open National Race Walking Championship (IND)        3.983333   5.216667
# Open National Race Walking Championship Kochi (...   3.933333   4.916667
# Pagdandi Ultra Run (IND)                             4.966667   7.766667
# Pune 100 km UltraMarathon (IND)                     12.166667  16.833333
# Pune 50 km UltraMarathon (IND)                       4.233333   7.633333
# Ruggedian Kolhapur Run (IND)                         3.916667   8.366667
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     6.350000  11.983333
# Shivalik Ultra Run 50 Km (IND)                       4.433333   9.450000
# Tata Ultra Marathon (IND)                            3.350000   8.200000
# The Border 100 - 100 Km Race (IND)                  11.683333  17.550000
# The Great Mawla Ghaati Ultra 50km (IND)              6.416667  12.900000
# The Malnad Ultra 50K (IND)                           4.633333   9.233333
# The Run of Raramuri Tribe (TRORT) (IND)              4.233333   7.950000
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           5.416667   8.400000
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           4.866667   8.350000
# Tuffman Stadium Run Chandigarh - 100km (IND)         7.783333  14.983333
# Two Oceans Marathon - 50km Split (RSA)               4.666667   6.433333
# Ultra Marathon Bengaluru (IND)                       3.616667   8.233333
# Ultra Marathon Bengaluru December (IND)              4.366667   8.700000
# Ultra Warrior Nainital (IND)                         5.083333  10.400000
# Ultribe Paderu (IND)                                 5.683333  10.650000
# Vagamon 50 Km Ultrail (IND)                          6.216667  10.750000
# Yercaud Hills Ultra (IND)                            5.700000   8.250000

# %%
most_performance_time=events_by_hours.sort_values(by='mean',ascending=False)
most_performance_time
# Out:
#                                                          mean  count  \
# Event name
# Hennur Bamboo 100 Km Ultra (IND)                    18.674444     90
# Jarakabande Eco Ultra 100 Km (IND)                  18.355556     27
# Bhatti Lakes 100 km (IND)                           16.203846     39
# Bangalore 100 km Ultra Marathon (IND)               15.286458     80
# Pune 100 km UltraMarathon (IND)                     15.018750     32
# The Border 100 - 100 Km Race (IND)                  14.980128     26
# Tuffman Stadium Run Chandigarh - 100km (IND)        11.155051     33
# The Great Mawla Ghaati Ultra 50km (IND)             10.074306     24
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     9.940240    111
# Mahabaleshwar Endurathon 50 km (IND)                 9.883333     43
# Bengaluru 100 km Stadium Run (IND)                   9.472581     31
# Ultribe Paderu (IND)                                 9.388889     33
# Vagamon 50 Km Ultrail (IND)                          9.263946     49
# Mount Abu Int. Trail Marathon (IND)                  9.136574     36
# Ultra Warrior Nainital (IND)                         8.367816     29
# Jarakabande Eco Ultra 50 Km (IND)                    8.152299     29
# The Malnad Ultra 50K (IND)                           8.107494    596
# Hennur Bamboo 50 Km Ultra (IND)                      7.594242    220
# Javadhu Hills Ultra 50 Km (IND)                      7.570833    104
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           7.144444     24
# Mahabaleshwar Endurathon (IND)                       7.068667     25
# Shivalik Ultra Run 50 Km (IND)                       6.951307     51
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           6.901923     26
# Mukteshwar Ultra Marathon (IND)                      6.852667     25
# Bhatti Lakes 30 miles (IND)                          6.797989     58
# Igatpuri Mountain Challenge (IND)                    6.704762     21
# The Run of Raramuri Tribe (TRORT) (IND)              6.671465     66
# Yercaud Hills Ultra (IND)                            6.661364     22
# Chennai Trail Marathon (IND)                         6.635069     48
# Pagdandi Ultra Run (IND)                             6.611742     44
# Matheran Endurathon (IND)                            6.570940     78
# Bangalore 50 km Ultra Marathon (IND)                 6.420788    182
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         6.398485     22
# Matheran Endurathon - Summer Edition 50km (IND)      6.359524     28
# Ultra Marathon Bengaluru December (IND)              6.350000     51
# Lonavala Varsha Marathon (IND)                       6.272222     24
# Tata Ultra Marathon (IND)                            6.080478    467
# Hyderabad Ultra Marathon (IND)                       6.070202     66
# BNP Ultra (IND)                                      6.024272    103
# Ultra Marathon Bengaluru (IND)                       5.993333    115
# Pune 50 km UltraMarathon (IND)                       5.940556     30
# Chambal Challenge - Chambal Maharana 50 Km (IND)     5.904487     26
# Ruggedian Kolhapur Run (IND)                         5.803241     36
# Two Oceans Marathon - 50km Split (RSA)               5.753401     49
# Open National Race Walking Championship (IND)        4.526087     23
# Open National Race Walking Championship Kochi (...   4.338384     33
#
#                                                           min        max
# Event name
# Hennur Bamboo 100 Km Ultra (IND)                    11.600000  23.916667
# Jarakabande Eco Ultra 100 Km (IND)                  12.750000  22.566667
# Bhatti Lakes 100 km (IND)                           11.866667  17.933333
# Bangalore 100 km Ultra Marathon (IND)               10.100000  23.233333
# Pune 100 km UltraMarathon (IND)                     12.166667  16.833333
# The Border 100 - 100 Km Race (IND)                  11.683333  17.550000
# Tuffman Stadium Run Chandigarh - 100km (IND)         7.783333  14.983333
# The Great Mawla Ghaati Ultra 50km (IND)              6.416667  12.900000
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     6.350000  11.983333
# Mahabaleshwar Endurathon 50 km (IND)                 6.200000  15.250000
# Bengaluru 100 km Stadium Run (IND)                   7.933333  13.350000
# Ultribe Paderu (IND)                                 5.683333  10.650000
# Vagamon 50 Km Ultrail (IND)                          6.216667  10.750000
# Mount Abu Int. Trail Marathon (IND)                  4.900000  11.333333
# Ultra Warrior Nainital (IND)                         5.083333  10.400000
# Jarakabande Eco Ultra 50 Km (IND)                    4.966667  18.250000
# The Malnad Ultra 50K (IND)                           4.633333   9.233333
# Hennur Bamboo 50 Km Ultra (IND)                      4.233333  13.650000
# Javadhu Hills Ultra 50 Km (IND)                      4.683333  10.583333
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           4.866667   8.350000
# Mahabaleshwar Endurathon (IND)                       5.033333  10.416667
# Shivalik Ultra Run 50 Km (IND)                       4.433333   9.450000
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           5.416667   8.400000
# Mukteshwar Ultra Marathon (IND)                      4.850000   8.200000
# Bhatti Lakes 30 miles (IND)                          4.950000   8.000000
# Igatpuri Mountain Challenge (IND)                    5.266667   7.883333
# The Run of Raramuri Tribe (TRORT) (IND)              4.233333   7.950000
# Yercaud Hills Ultra (IND)                            5.700000   8.250000
# Chennai Trail Marathon (IND)                         4.750000   8.433333
# Pagdandi Ultra Run (IND)                             4.966667   7.766667
# Matheran Endurathon (IND)                            4.266667   9.383333
# Bangalore 50 km Ultra Marathon (IND)                 3.933333   9.600000
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         4.083333   7.533333
# Matheran Endurathon - Summer Edition 50km (IND)      4.450000   7.933333
# Ultra Marathon Bengaluru December (IND)              4.366667   8.700000
# Lonavala Varsha Marathon (IND)                       4.200000   9.300000
# Tata Ultra Marathon (IND)                            3.350000   8.200000
# Hyderabad Ultra Marathon (IND)                       3.450000   9.183333
# BNP Ultra (IND)                                      3.933333   8.066667
# Ultra Marathon Bengaluru (IND)                       3.616667   8.233333
# Pune 50 km UltraMarathon (IND)                       4.233333   7.633333
# Chambal Challenge - Chambal Maharana 50 Km (IND)     4.000000   7.616667
# Ruggedian Kolhapur Run (IND)                         3.916667   8.366667
# Two Oceans Marathon - 50km Split (RSA)               4.666667   6.433333
# Open National Race Walking Championship (IND)        3.983333   5.216667
# Open National Race Walking Championship Kochi (...   3.933333   4.916667

# %%
plt.figure(figsize=(10, 6))
plt.plot(most_performance_time.head().index, most_performance_time.head()['mean'], marker='o', color='b', linestyle='-')
plt.xlabel('Event name')
plt.ylabel('Time in hours')
plt.title('Top 5 Event name that has most performance time in hours')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
fastest_Finish=events_by_hours.sort_values(by='min',ascending=True)
fastest_Finish
# Out:
#                                                          mean  count  \
# Event name
# Tata Ultra Marathon (IND)                            6.080478    467
# Hyderabad Ultra Marathon (IND)                       6.070202     66
# Ultra Marathon Bengaluru (IND)                       5.993333    115
# Ruggedian Kolhapur Run (IND)                         5.803241     36
# BNP Ultra (IND)                                      6.024272    103
# Open National Race Walking Championship Kochi (...   4.338384     33
# Bangalore 50 km Ultra Marathon (IND)                 6.420788    182
# Open National Race Walking Championship (IND)        4.526087     23
# Chambal Challenge - Chambal Maharana 50 Km (IND)     5.904487     26
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         6.398485     22
# Lonavala Varsha Marathon (IND)                       6.272222     24
# The Run of Raramuri Tribe (TRORT) (IND)              6.671465     66
# Pune 50 km UltraMarathon (IND)                       5.940556     30
# Hennur Bamboo 50 Km Ultra (IND)                      7.594242    220
# Matheran Endurathon (IND)                            6.570940     78
# Ultra Marathon Bengaluru December (IND)              6.350000     51
# Shivalik Ultra Run 50 Km (IND)                       6.951307     51
# Matheran Endurathon - Summer Edition 50km (IND)      6.359524     28
# The Malnad Ultra 50K (IND)                           8.107494    596
# Two Oceans Marathon - 50km Split (RSA)               5.753401     49
# Javadhu Hills Ultra 50 Km (IND)                      7.570833    104
# Chennai Trail Marathon (IND)                         6.635069     48
# Mukteshwar Ultra Marathon (IND)                      6.852667     25
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           7.144444     24
# Mount Abu Int. Trail Marathon (IND)                  9.136574     36
# Bhatti Lakes 30 miles (IND)                          6.797989     58
# Pagdandi Ultra Run (IND)                             6.611742     44
# Jarakabande Eco Ultra 50 Km (IND)                    8.152299     29
# Mahabaleshwar Endurathon (IND)                       7.068667     25
# Ultra Warrior Nainital (IND)                         8.367816     29
# Igatpuri Mountain Challenge (IND)                    6.704762     21
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           6.901923     26
# Ultribe Paderu (IND)                                 9.388889     33
# Yercaud Hills Ultra (IND)                            6.661364     22
# Mahabaleshwar Endurathon 50 km (IND)                 9.883333     43
# Vagamon 50 Km Ultrail (IND)                          9.263946     49
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     9.940240    111
# The Great Mawla Ghaati Ultra 50km (IND)             10.074306     24
# Tuffman Stadium Run Chandigarh - 100km (IND)        11.155051     33
# Bengaluru 100 km Stadium Run (IND)                   9.472581     31
# Bangalore 100 km Ultra Marathon (IND)               15.286458     80
# Hennur Bamboo 100 Km Ultra (IND)                    18.674444     90
# The Border 100 - 100 Km Race (IND)                  14.980128     26
# Bhatti Lakes 100 km (IND)                           16.203846     39
# Pune 100 km UltraMarathon (IND)                     15.018750     32
# Jarakabande Eco Ultra 100 Km (IND)                  18.355556     27
#
#                                                           min        max
# Event name
# Tata Ultra Marathon (IND)                            3.350000   8.200000
# Hyderabad Ultra Marathon (IND)                       3.450000   9.183333
# Ultra Marathon Bengaluru (IND)                       3.616667   8.233333
# Ruggedian Kolhapur Run (IND)                         3.916667   8.366667
# BNP Ultra (IND)                                      3.933333   8.066667
# Open National Race Walking Championship Kochi (...   3.933333   4.916667
# Bangalore 50 km Ultra Marathon (IND)                 3.933333   9.600000
# Open National Race Walking Championship (IND)        3.983333   5.216667
# Chambal Challenge - Chambal Maharana 50 Km (IND)     4.000000   7.616667
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         4.083333   7.533333
# Lonavala Varsha Marathon (IND)                       4.200000   9.300000
# The Run of Raramuri Tribe (TRORT) (IND)              4.233333   7.950000
# Pune 50 km UltraMarathon (IND)                       4.233333   7.633333
# Hennur Bamboo 50 Km Ultra (IND)                      4.233333  13.650000
# Matheran Endurathon (IND)                            4.266667   9.383333
# Ultra Marathon Bengaluru December (IND)              4.366667   8.700000
# Shivalik Ultra Run 50 Km (IND)                       4.433333   9.450000
# Matheran Endurathon - Summer Edition 50km (IND)      4.450000   7.933333
# The Malnad Ultra 50K (IND)                           4.633333   9.233333
# Two Oceans Marathon - 50km Split (RSA)               4.666667   6.433333
# Javadhu Hills Ultra 50 Km (IND)                      4.683333  10.583333
# Chennai Trail Marathon (IND)                         4.750000   8.433333
# Mukteshwar Ultra Marathon (IND)                      4.850000   8.200000
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           4.866667   8.350000
# Mount Abu Int. Trail Marathon (IND)                  4.900000  11.333333
# Bhatti Lakes 30 miles (IND)                          4.950000   8.000000
# Pagdandi Ultra Run (IND)                             4.966667   7.766667
# Jarakabande Eco Ultra 50 Km (IND)                    4.966667  18.250000
# Mahabaleshwar Endurathon (IND)                       5.033333  10.416667
# Ultra Warrior Nainital (IND)                         5.083333  10.400000
# Igatpuri Mountain Challenge (IND)                    5.266667   7.883333
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           5.416667   8.400000
# Ultribe Paderu (IND)                                 5.683333  10.650000
# Yercaud Hills Ultra (IND)                            5.700000   8.250000
# Mahabaleshwar Endurathon 50 km (IND)                 6.200000  15.250000
# Vagamon 50 Km Ultrail (IND)                          6.216667  10.750000
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     6.350000  11.983333
# The Great Mawla Ghaati Ultra 50km (IND)              6.416667  12.900000
# Tuffman Stadium Run Chandigarh - 100km (IND)         7.783333  14.983333
# Bengaluru 100 km Stadium Run (IND)                   7.933333  13.350000
# Bangalore 100 km Ultra Marathon (IND)               10.100000  23.233333
# Hennur Bamboo 100 Km Ultra (IND)                    11.600000  23.916667
# The Border 100 - 100 Km Race (IND)                  11.683333  17.550000
# Bhatti Lakes 100 km (IND)                           11.866667  17.933333
# Pune 100 km UltraMarathon (IND)                     12.166667  16.833333
# Jarakabande Eco Ultra 100 Km (IND)                  12.750000  22.566667

# %%
plt.figure(figsize=(10, 6))
plt.bar(fastest_Finish.head().index, fastest_Finish.head()['min'])
plt.xlabel('Event name')
plt.ylabel('Time in hours')
plt.title('Top 5 Event with fastest Finish')
plt.xticks(rotation=45)
plt.show()

# %%
Slowest_Finish=events_by_hours.sort_values(by='max',ascending=False)
Slowest_Finish
# Out:
#                                                          mean  count  \
# Event name
# Hennur Bamboo 100 Km Ultra (IND)                    18.674444     90
# Bangalore 100 km Ultra Marathon (IND)               15.286458     80
# Jarakabande Eco Ultra 100 Km (IND)                  18.355556     27
# Jarakabande Eco Ultra 50 Km (IND)                    8.152299     29
# Bhatti Lakes 100 km (IND)                           16.203846     39
# The Border 100 - 100 Km Race (IND)                  14.980128     26
# Pune 100 km UltraMarathon (IND)                     15.018750     32
# Mahabaleshwar Endurathon 50 km (IND)                 9.883333     43
# Tuffman Stadium Run Chandigarh - 100km (IND)        11.155051     33
# Hennur Bamboo 50 Km Ultra (IND)                      7.594242    220
# Bengaluru 100 km Stadium Run (IND)                   9.472581     31
# The Great Mawla Ghaati Ultra 50km (IND)             10.074306     24
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     9.940240    111
# Mount Abu Int. Trail Marathon (IND)                  9.136574     36
# Vagamon 50 Km Ultrail (IND)                          9.263946     49
# Ultribe Paderu (IND)                                 9.388889     33
# Javadhu Hills Ultra 50 Km (IND)                      7.570833    104
# Mahabaleshwar Endurathon (IND)                       7.068667     25
# Ultra Warrior Nainital (IND)                         8.367816     29
# Bangalore 50 km Ultra Marathon (IND)                 6.420788    182
# Shivalik Ultra Run 50 Km (IND)                       6.951307     51
# Matheran Endurathon (IND)                            6.570940     78
# Lonavala Varsha Marathon (IND)                       6.272222     24
# The Malnad Ultra 50K (IND)                           8.107494    596
# Hyderabad Ultra Marathon (IND)                       6.070202     66
# Ultra Marathon Bengaluru December (IND)              6.350000     51
# Chennai Trail Marathon (IND)                         6.635069     48
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           6.901923     26
# Ruggedian Kolhapur Run (IND)                         5.803241     36
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           7.144444     24
# Yercaud Hills Ultra (IND)                            6.661364     22
# Ultra Marathon Bengaluru (IND)                       5.993333    115
# Mukteshwar Ultra Marathon (IND)                      6.852667     25
# Tata Ultra Marathon (IND)                            6.080478    467
# BNP Ultra (IND)                                      6.024272    103
# Bhatti Lakes 30 miles (IND)                          6.797989     58
# The Run of Raramuri Tribe (TRORT) (IND)              6.671465     66
# Matheran Endurathon - Summer Edition 50km (IND)      6.359524     28
# Igatpuri Mountain Challenge (IND)                    6.704762     21
# Pagdandi Ultra Run (IND)                             6.611742     44
# Pune 50 km UltraMarathon (IND)                       5.940556     30
# Chambal Challenge - Chambal Maharana 50 Km (IND)     5.904487     26
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         6.398485     22
# Two Oceans Marathon - 50km Split (RSA)               5.753401     49
# Open National Race Walking Championship (IND)        4.526087     23
# Open National Race Walking Championship Kochi (...   4.338384     33
#
#                                                           min        max
# Event name
# Hennur Bamboo 100 Km Ultra (IND)                    11.600000  23.916667
# Bangalore 100 km Ultra Marathon (IND)               10.100000  23.233333
# Jarakabande Eco Ultra 100 Km (IND)                  12.750000  22.566667
# Jarakabande Eco Ultra 50 Km (IND)                    4.966667  18.250000
# Bhatti Lakes 100 km (IND)                           11.866667  17.933333
# The Border 100 - 100 Km Race (IND)                  11.683333  17.550000
# Pune 100 km UltraMarathon (IND)                     12.166667  16.833333
# Mahabaleshwar Endurathon 50 km (IND)                 6.200000  15.250000
# Tuffman Stadium Run Chandigarh - 100km (IND)         7.783333  14.983333
# Hennur Bamboo 50 Km Ultra (IND)                      4.233333  13.650000
# Bengaluru 100 km Stadium Run (IND)                   7.933333  13.350000
# The Great Mawla Ghaati Ultra 50km (IND)              6.416667  12.900000
# SRT Ultra Marathon (Sinhagad-Rajgad-Torna) (IND)     6.350000  11.983333
# Mount Abu Int. Trail Marathon (IND)                  4.900000  11.333333
# Vagamon 50 Km Ultrail (IND)                          6.216667  10.750000
# Ultribe Paderu (IND)                                 5.683333  10.650000
# Javadhu Hills Ultra 50 Km (IND)                      4.683333  10.583333
# Mahabaleshwar Endurathon (IND)                       5.033333  10.416667
# Ultra Warrior Nainital (IND)                         5.083333  10.400000
# Bangalore 50 km Ultra Marathon (IND)                 3.933333   9.600000
# Shivalik Ultra Run 50 Km (IND)                       4.433333   9.450000
# Matheran Endurathon (IND)                            4.266667   9.383333
# Lonavala Varsha Marathon (IND)                       4.200000   9.300000
# The Malnad Ultra 50K (IND)                           4.633333   9.233333
# Hyderabad Ultra Marathon (IND)                       3.450000   9.183333
# Ultra Marathon Bengaluru December (IND)              4.366667   8.700000
# Chennai Trail Marathon (IND)                         4.750000   8.433333
# Tuffman Shimla Ultra 4.0 - 50 Km Run (IND)           5.416667   8.400000
# Ruggedian Kolhapur Run (IND)                         3.916667   8.366667
# Tuffman Shimla Ultra 5.0 - 50 Km Run (IND)           4.866667   8.350000
# Yercaud Hills Ultra (IND)                            5.700000   8.250000
# Ultra Marathon Bengaluru (IND)                       3.616667   8.233333
# Mukteshwar Ultra Marathon (IND)                      4.850000   8.200000
# Tata Ultra Marathon (IND)                            3.350000   8.200000
# BNP Ultra (IND)                                      3.933333   8.066667
# Bhatti Lakes 30 miles (IND)                          4.950000   8.000000
# The Run of Raramuri Tribe (TRORT) (IND)              4.233333   7.950000
# Matheran Endurathon - Summer Edition 50km (IND)      4.450000   7.933333
# Igatpuri Mountain Challenge (IND)                    5.266667   7.883333
# Pagdandi Ultra Run (IND)                             4.966667   7.766667
# Pune 50 km UltraMarathon (IND)                       4.233333   7.633333
# Chambal Challenge - Chambal Maharana 50 Km (IND)     4.000000   7.616667
# GSR Tuffman Goa Beach Darling Ultra 50 (IND)         4.083333   7.533333
# Two Oceans Marathon - 50km Split (RSA)               4.666667   6.433333
# Open National Race Walking Championship (IND)        3.983333   5.216667
# Open National Race Walking Championship Kochi (...   3.933333   4.916667

# %%
plt.figure(figsize=(10, 6))
plt.bar(Slowest_Finish.head().index, Slowest_Finish.head()['max'],color='green')
plt.xlabel('Event name')
plt.ylabel('Time in hours')
plt.title('Top 5 Event with slowest Finish')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # season in india
# #  spring 2-3
# # summer 4-8
# # fall 9-11
# # winter 11-2

# %%
df['seasons']=df['Event dates'].dt.month.apply(lambda x: 'winter' if x > 11 else 'fall' if x > 8 else 'summer' if x > 3 else 'spring' if x > 2 else 'winter')
df
# Out:
#         index  Year of event Event dates  \
# 0        5843           2018  2018-03-18
# 1       16245           2018  2018-03-17
# 2       23416           2018  2018-03-10
# 3       24745           2018  2018-03-10
# 4       25299           2018  2018-03-10
# ...       ...            ...         ...
# 6348  6776097           2015         NaT
# 6349  6783641           2015  2015-10-31
# 6350  6819032           2015  2015-10-10
# 6351  6821563           2015  2015-10-10
# 6352  6821569           2015  2015-10-10
#
#                                        Event name Event distance/length  \
# 0             TITI 50km Road Ultra Marathon (MAS)                  50km
# 1                           Om Die Dam 50km (RSA)                  50km
# 2                             North C Trail (BEL)                  50km
# 3               Crazy Desert Trail Race 50k (USA)                  50km
# 4                       Dirty Duo Trail Run (CAN)                  50km
# ...                                           ...                   ...
# 6348       Bangalore 24 hour Ultra Marathon (IND)                   24h
# 6349  Bedok Reservoir 12 hour Ultramarathon (SGP)                   12h
# 6350            The North Face 50 Singapore (SGP)                  50km
# 6351              Annapurna 50k Ultra Trail (NEP)                  50km
# 6352              Annapurna 50k Ultra Trail (NEP)                  50km
#
#       Event number of finishers Athlete performance Athlete country  \
# 0                           282 2024-06-14 08:44:07             IND
# 1                          2491 2024-06-14 05:18:55             IND
# 2                           192 2024-06-14 08:04:30             IND
# 3                            59 2024-06-14 06:21:38             IND
# 4                            34 2024-06-14 04:58:08             IND
# ...                         ...                 ...             ...
# 6348                         25                 NaT             IND
# 6349                        148                 NaT             IND
# 6350                        269 2024-06-14 03:58:20             IND
# 6351                         36 2024-06-14 12:40:30             IND
# 6352                         36 2024-06-14 14:04:20             IND
#
#      Athlete gender Athlete age category  Athlete average speed  Athlete ID  \
# 0                 M                  M40                  5.724        5211
# 1                 M                  M23                  9.407       15497
# 2                 F                  W23                  6.192       22117
# 3                 M                  M23                  7.861       23372
# 4                 M                  M35                 10.063       23912
# ...             ...                  ...                    ...         ...
# 6348              F                  W35                  4.250       68462
# 6349              M                  M35                  4.300       25241
# 6350              M                  M35                 12.587       23912
# 6351              M                  M35                  3.945      396014
# 6352              M                  M35                  3.553      444467
#
#       Athlete_Age  Athlete_performance_in_hours seasons
# 0              41                      8.733333  spring
# 1              30                      5.300000  spring
# 2              28                      8.066667  spring
# 3              31                      6.350000  spring
# 4              38                      4.966667  spring
# ...           ...                           ...     ...
# 6348           35                           NaN  winter
# 6349           37                           NaN    fall
# 6350           35                      3.966667    fall
# 6351           39                     12.666667    fall
# 6352           39                     14.066667    fall
#
# [6353 rows x 15 columns]

# %%
season_count=df.seasons.value_counts()
season_count
# Out:
# seasons
# winter    3453
# fall      1678
# summer     990
# spring     232
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
px.pie(names=season_count.index,values=season_count.values,hole=.6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3300bbe0-6dca-42d2-8012-2f1a1ed1370d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3300bbe0-6dca-42d2-8012-2f1a1ed1370d")) {                    Plotly.newPlot(                        "3300bbe0-6dca-42d2-8012-2f1a1ed1370d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["winter","fall","summer","spring"],"legendgroup":"","name":"","showlegend":true,"values":[3453,1678,990,232],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"tic ...
